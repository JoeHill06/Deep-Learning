# %% [markdown]
# # MNIST Convolutional Neural Network (Keras)
#
#   The MNIST training images are all perfectly centred, upright, and similarly sized. This causes the network to overfit to these specific conditions — it learns to recognise a "7" that sits in the middle of the
#   frame at a particular scale, rather than learning what a "7" actually looks like regardless of position, size, or slight rotation. In the real world, handwritten digits won't be perfectly framed, so a model
#   trained only on pristine examples is more brittle than its 99% test accuracy suggests.
#
#   Data augmentation fixes this by applying small random transformations (shifts, rotations, zooms) to each training image on the fly, so the network never sees the exact same image twice. This artificially
#   increases the diversity of the training set without collecting new data, and forces the network to learn features that are invariant to position, angle, and scale — which is what we actually want from a digit
#   classifier.
#
#
# **Architecture:**
# `28×28×1 input → Conv(64, 3×3) → MaxPool(2×2) → Conv(64, 3×3) → MaxPool(2×2) → Flatten → Dense(128, tanh) → Dropout(0.3) → Dense(128, tanh) → Dropout(0.3) → Dense(10, softmax)`
#
# **Techniques:** TensorFlow/Keras high-level API · Convolutional + max-pooling layers · ReLU + tanh + softmax activations · Dropout regularisation · Sparse categorical cross-entropy loss · Adam optimiser · `validation_split` + `EarlyStopping` to prevent overfitting
#
# **Classes:** Digits 0–9
#
# This notebook is the Keras counterpart to the from-scratch NumPy MNIST notebook (Network 1). The point is to compare a hand-rolled mini-batch SGD on a plain MLP against the high-level Keras API with a small CNN, and to show the standard tools (dropout, validation split, early stopping) that close the train/test gap.
#
# **Result: ~99.2% test accuracy**
# Final training accuracy : 99.2%  (loss 0.026)
# Final validation acc.   : 99.2%  (loss 0.044)
# Test accuracy           : 99.2%  (loss 0.024)
# Train/test gap          : -0.0%

# %% [markdown]
# Installing Dependencies

# %%
# install tensorflow 
# %pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/joehill/Developer/DeepLearning/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# ── Imports ───────────────────────────────────────────────────────────────
# MNIST dataset loader (ships with Keras)
from keras.datasets import mnist

# TensorFlow / Keras — the deep-learning framework
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Numerical + plotting helpers
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loading our data

# %%
# getting our images
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# getting our training dimensions and counts
training_image_count, training_image_height, training_image_width = x_train.shape[0], x_train.shape[1], x_train.shape[2]

# getting our test dimensions and counts
test_image_count, test_image_height, test_image_width = x_test.shape[0], x_test.shape[1], x_test.shape[2]

# %% [markdown]
# Visulaising augmented digits

# %%
def show_augmented(n=20):
    """Show n random training images alongside their augmented versions."""
    # Build a mini model that ONLY contains the augmentation layers.
    # Calling it in training mode applies the random transforms.
    aug = tf.keras.Sequential([
        tf.keras.layers.RandomRotation(0.1),
        tf.keras.layers.RandomTranslation(0.2, 0.25),
        tf.keras.layers.RandomZoom(0.25),
    ])

    indices = np.random.randint(0, len(training_images), n)

    cols = 5
    rows = n // cols
    fig, axes = plt.subplots(rows, cols * 2, figsize=(cols * 4, rows * 2.5))

    for i, idx in enumerate(indices):
        row = i // cols
        col = i % cols

        original = training_images[idx]      # (28, 28, 1), already normalised
        augmented = aug(tf.expand_dims(original, 0), training=True)  # (1, 28, 28, 1)
        augmented = augmented[0]             # back to (28, 28, 1)

        # left column: original
        ax_orig = axes[row, col * 2]
        ax_orig.imshow(original[:, :, 0], cmap='gray')
        ax_orig.set_title(f"Original [{y_train[idx]}]", fontsize=7)
        ax_orig.axis('off')

        # right column: augmented
        ax_aug = axes[row, col * 2 + 1]
        ax_aug.imshow(augmented[:, :, 0].numpy(), cmap='gray')
        ax_aug.set_title(f"Augmented [{y_train[idx]}]", fontsize=7)
        ax_aug.axis('off')

    plt.suptitle("Original vs Augmented training images", fontsize=12)
    plt.tight_layout()
    plt.show()

show_augmented()

# %% [markdown]
# Building our model

# %%
# ── Hyperparameters ───────────────────────────────────────────────────────
input_size  = (training_image_height, training_image_width)  # (28, 28)
hidden_size = 128   # neurons in each fully-connected hidden layer
output_size = 10    # one output per digit class (0–9)
epochs      = 60    # max epochs

# %%
# Training settings 
num_train = 60000
num_test = 10000
batch_size = 100

# EarlyStopping callback settings
callbacks = [EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)]

# Peparing Data
training_images = (x_train[0:num_train] / 255.0).reshape(num_train, training_image_height, training_image_width, 1)
training_labels = y_train[0:num_train]

test_images = (x_test[0:num_test] / 255.0).reshape(num_test, test_image_height, test_image_width, 1)
test_labels = y_test[0:num_test]

# %%
# Building The Model
model = tf.keras.models.Sequential([
    # ── Data augmentation ──
    tf.keras.layers.RandomRotation(0.03),         # ±~10 degrees                                                                                                                                                        
    tf.keras.layers.RandomTranslation(0.05, 0.05), # ±5% shift
    tf.keras.layers.RandomZoom(0.05),              # ±5% zoom   


    # ── Convolutional feature extractor ──
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu',input_shape=(training_image_height, training_image_width, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),

    # ── Deep Neural Network ──
    # Layer_0
    tf.keras.layers.Flatten(),

    # Layer_1
    tf.keras.layers.Dense(hidden_size, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.15),

    # Layer_2
    tf.keras.layers.Dense(hidden_size, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.15),

    # Output layer:
    tf.keras.layers.Dense(output_size, activation=tf.nn.softmax),
])

# ── Compile ───────────────────────────────────────────────────────────────
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# ── Train ─────────────────────────────────────────────────────────────────
print("Training…\n")
history = model.fit(training_images, 
                    training_labels,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_split=0.1,
                    callbacks=callbacks,
                    verbose=2)

# ── Evaluate on the held-out test set ─────────────────────────────────────
print("\nEvaluating on test set…")
test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=0)

# ── Final summary ─────────────────────────────────────────────────────────
final_train_accuracy = history.history["accuracy"][-1]
final_train_loss     = history.history["loss"][-1]
final_val_accuracy   = history.history["val_accuracy"][-1]
final_val_loss       = history.history["val_loss"][-1]
epochs_run           = len(history.history["loss"])

print("\n── Results ───────────────────────────────────────────────")
print(f"Epochs run              : {epochs_run} (of {epochs} requested)")
print(f"Final training accuracy : {final_train_accuracy * 100:.1f}%  (loss {final_train_loss:.3f})")
print(f"Final validation acc.   : {final_val_accuracy   * 100:.1f}%  (loss {final_val_loss:.3f})")
print(f"Test accuracy           : {test_accuracy        * 100:.1f}%  (loss {test_loss:.3f})")
print(f"Train/test gap          : {(final_train_accuracy - test_accuracy) * 100:+.1f}%")
# Out:
# Training…
#
# Epoch 1/60
# 540/540 - 7s - 13ms/step - accuracy: 0.8989 - loss: 0.3226 - val_accuracy: 0.9825 - val_loss: 0.0594
# Epoch 2/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9662 - loss: 0.1090 - val_accuracy: 0.9882 - val_loss: 0.0395
# Epoch 3/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9753 - loss: 0.0811 - val_accuracy: 0.9898 - val_loss: 0.0338
# Epoch 4/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9803 - loss: 0.0645 - val_accuracy: 0.9918 - val_loss: 0.0308
# Epoch 5/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9832 - loss: 0.0543 - val_accuracy: 0.9925 - val_loss: 0.0274
# Epoch 6/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9848 - loss: 0.0497 - val_accuracy: 0.9930 - val_loss: 0.0287
# Epoch 7/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9863 - loss: 0.0461 - val_accuracy: 0.9908 - val_loss: 0.0354
# Epoch 8/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9875 - loss: 0.0419 - val_accuracy: 0.9942 - val_loss: 0.0302
# Epoch 9/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9889 - loss: 0.0374 - val_accuracy: 0.9928 - val_loss: 0.0344
# Epoch 10/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9891 - loss: 0.0346 - val_accuracy: 0.9925 - val_loss: 0.0368
# Epoch 11/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9896 - loss: 0.0340 - val_accuracy: 0.9932 - val_loss: 0.0331
# Epoch 12/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9901 - loss: 0.0304 - val_accuracy: 0.9925 - val_loss: 0.0328
# Epoch 13/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9907 - loss: 0.0301 - val_accuracy: 0.9943 - val_loss: 0.0305
# Epoch 14/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9910 - loss: 0.0283 - val_accuracy: 0.9915 - val_loss: 0.0377
# Epoch 15/60
# 540/540 - 6s - 11ms/step - accuracy: 0.9919 - loss: 0.0264 - val_accuracy: 0.9923 - val_loss: 0.0444
#
# Evaluating on test set…
#
# ── Results ───────────────────────────────────────────────
# Epochs run              : 15 (of 60 requested)
# Final training accuracy : 99.2%  (loss 0.026)
# Final validation acc.   : 99.2%  (loss 0.044)
# Test accuracy           : 99.2%  (loss 0.024)
# Train/test gap          : -0.0%

# %%
# saving the model
model.save("mnist_cnn.keras")
print("Saved → mnist_cnn.keras")
# Out:
# Saved → mnist_cnn.keras
